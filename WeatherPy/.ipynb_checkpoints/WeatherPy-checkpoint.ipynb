# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 641

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Convert list of cities into DataFrame so data can be imported from API
cities_df = pd.DataFrame({"City":cities})
cities_df
# Out:
#                 City
# 0          flagstaff
# 1             hasaki
# 2       port lincoln
# 3          taolanaro
# 4    lazaro cardenas
# ..               ...
# 636       narathiwat
# 637          albanel
# 638            altay
# 639            dondo
# 640       baker city
#
# [641 rows x 1 columns]

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"

#Set up empty columns for data in Dataframe
cities_df["Cloudiness"] = ""
cities_df["Country"] = ""
cities_df["Date"] = ""
cities_df["Humidity"] = ""
cities_df["Lat"] = ""
cities_df["Lng"] = ""
cities_df["Max Temp"] = ""
cities_df["Wind Speed"] = ""

print("Beginning Data Retrieval")
print("-"*25)

#Perform a series of successive API calls to fill DataFrame with data
for index, row in cities_df.iterrows():
    city = row["City"]
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    try:
        print(f"Processing Record {index} of Set | {city}")
        cities_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        cities_df.loc[index, "Country"] = response["sys"]["country"]
        cities_df.loc[index, "Date"] = response["dt"]
        cities_df.loc[index, "Humidity"] = response["main"]["humidity"]
        cities_df.loc[index, "Lat"] = response["coord"]["lat"]
        cities_df.loc[index, "Lng"] = response["coord"]["lon"]
        cities_df.loc[index, "Max Temp"] = response["main"]["temp_max"]
        cities_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
    except (KeyError, IndexError):
        print("City not found... skipping")
        pass
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 0 of Set | flagstaff
# Processing Record 1 of Set | hasaki
# Processing Record 2 of Set | port lincoln
# Processing Record 3 of Set | taolanaro
# City not found... skipping
# Processing Record 4 of Set | lazaro cardenas
# Processing Record 5 of Set | lebu
# Processing Record 6 of Set | mahebourg
# Processing Record 7 of Set | nueva loja
# Processing Record 8 of Set | salamiyah
# Processing Record 9 of Set | riyadh
# Processing Record 10 of Set | punta arenas
# Processing Record 11 of Set | merauke
# Processing Record 12 of Set | kaka
# Processing Record 13 of Set | palabuhanratu
# City not found... skipping
# Processing Record 14 of Set | ramanuj ganj
# Processing Record 15 of Set | rikitea
# Processing Record 16 of Set | alofi
# Processing Record 17 of Set | saint-augustin
# Processing Record 18 of Set | guerrero negro
# Processing Record 19 of Set | port alfred
# Processing Record 20 of Set | clyde river
# Processing Record 21 of Set | tuktoyaktuk
# Processing Record 22 of Set | lagoa
# Processing Record 23 of Set | busselton
# Processing Record 24 of Set | namibe
# Processing Record 25 of Set | puerto ayora
# Processing Record 26 of Set | khatanga
# Processing Record 27 of Set | narsaq
# Processing Record 28 of Set | bani walid
# Processing Record 29 of Set | nikolskoye
# Processing Record 30 of Set | bluff
# Processing Record 31 of Set | samusu
# City not found... skipping
# Processing Record 32 of Set | bredasdorp
# Processing Record 33 of Set | mar del plata
# Processing Record 34 of Set | avarua
# Processing Record 35 of Set | new norfolk
# Processing Record 36 of Set | saskylakh
# Processing Record 37 of Set | quatre cocos
# Processing Record 38 of Set | saint-philippe
# Processing Record 39 of Set | vaini
# Processing Record 40 of Set | mataura
# Processing Record 41 of Set | azimur
# City not found... skipping
# Processing Record 42 of Set | ushuaia
# Processing Record 43 of Set | bengkulu
# Processing Record 44 of Set | oda
# Processing Record 45 of Set | saleaula
# City not found... skipping
# Processing Record 46 of Set | atuona
# Processing Record 47 of Set | horasan
# Processing Record 48 of Set | myaundzha
# Processing Record 49 of Set | barrow
# Processing Record 50 of Set | san patricio
# Processing Record 51 of Set | vardo
# Processing Record 52 of Set | porto walter
# Processing Record 53 of Set | kholm
# Processing Record 54 of Set | pag
# Processing Record 55 of Set | korla
# Processing Record 56 of Set | hopfgarten
# Processing Record 57 of Set | manavalakurichi
# Processing Record 58 of Set | two rivers
# Processing Record 59 of Set | turan
# Processing Record 60 of Set | attawapiskat
# City not found... skipping
# Processing Record 61 of Set | roma
# Processing Record 62 of Set | bethel
# Processing Record 63 of Set | porto santo
# Processing Record 64 of Set | sinnamary
# Processing Record 65 of Set | mount gambier
# Processing Record 66 of Set | broome
# Processing Record 67 of Set | marystown
# Processing Record 68 of Set | upernavik
# Processing Record 69 of Set | nizhneyansk
# City not found... skipping
# Processing Record 70 of Set | desna
# Processing Record 71 of Set | hobart
# Processing Record 72 of Set | miraflores
# Processing Record 73 of Set | cheuskiny
# City not found... skipping
# Processing Record 74 of Set | luderitz
# Processing Record 75 of Set | chuy
# Processing Record 76 of Set | faanui
# Processing Record 77 of Set | uyemskiy
# Processing Record 78 of Set | bambous virieux
# Processing Record 79 of Set | nuevo progreso
# Processing Record 80 of Set | longyearbyen
# Processing Record 81 of Set | castro
# Processing Record 82 of Set | karamay
# City not found... skipping
# Processing Record 83 of Set | chokurdakh
# Processing Record 84 of Set | kapaa
# Processing Record 85 of Set | dikson
# Processing Record 86 of Set | qaanaaq
# Processing Record 87 of Set | ayr
# Processing Record 88 of Set | karla
# Processing Record 89 of Set | gangoh
# Processing Record 90 of Set | araguacu
# Processing Record 91 of Set | coihaique
# Processing Record 92 of Set | la cruz
# Processing Record 93 of Set | pasuruan
# Processing Record 94 of Set | nikki
# Processing Record 95 of Set | pangoa
# Processing Record 96 of Set | belushya guba
# City not found... skipping
# Processing Record 97 of Set | kallaste
# Processing Record 98 of Set | yerbogachen
# Processing Record 99 of Set | bacungan
# Processing Record 100 of Set | kedrovyy
# Processing Record 101 of Set | bondo
# Processing Record 102 of Set | praia
# Processing Record 103 of Set | ancud
# Processing Record 104 of Set | leningradskiy
# Processing Record 105 of Set | port hardy
# Processing Record 106 of Set | victoria
# Processing Record 107 of Set | canas
# Processing Record 108 of Set | cape town
# Processing Record 109 of Set | arraial do cabo
# Processing Record 110 of Set | andevoranto
# City not found... skipping
# Processing Record 111 of Set | ossora
# Processing Record 112 of Set | hudson bay
# Processing Record 113 of Set | sao joao da barra
# Processing Record 114 of Set | kaitangata
# Processing Record 115 of Set | banmo
# City not found... skipping
# Processing Record 116 of Set | butaritari
# Processing Record 117 of Set | port elizabeth
# Processing Record 118 of Set | sturgeon falls
# Processing Record 119 of Set | anadyr
# Processing Record 120 of Set | atocha
# Processing Record 121 of Set | half moon bay
# Processing Record 122 of Set | udon thani
# Processing Record 123 of Set | rio gallegos
# Processing Record 124 of Set | maragogi
# Processing Record 125 of Set | pa sang
# Processing Record 126 of Set | ardakan
# Processing Record 127 of Set | kidal
# Processing Record 128 of Set | coahuayana
# Processing Record 129 of Set | nimaparha
# Processing Record 130 of Set | vershino-darasunskiy
# Processing Record 131 of Set | vila velha
# Processing Record 132 of Set | qinhuangdao
# Processing Record 133 of Set | albany
# Processing Record 134 of Set | wangou
# Processing Record 135 of Set | ishigaki
# Processing Record 136 of Set | okato
# Processing Record 137 of Set | kodiak
# Processing Record 138 of Set | rocha
# Processing Record 139 of Set | nguiu
# City not found... skipping
# Processing Record 140 of Set | yar-sale
# Processing Record 141 of Set | hambantota
# Processing Record 142 of Set | cabedelo
# Processing Record 143 of Set | bambanglipuro
# Processing Record 144 of Set | jamestown
# Processing Record 145 of Set | kulim
# Processing Record 146 of Set | mandal
# Processing Record 147 of Set | birin
# Processing Record 148 of Set | dingle
# Processing Record 149 of Set | mana
# Processing Record 150 of Set | sabha
# Processing Record 151 of Set | lata
# Processing Record 152 of Set | balakovo
# Processing Record 153 of Set | husavik
# Processing Record 154 of Set | benguela
# Processing Record 155 of Set | xining
# Processing Record 156 of Set | nara
# Processing Record 157 of Set | hofn
# Processing Record 158 of Set | cabra
# Processing Record 159 of Set | mys shmidta
# City not found... skipping
# Processing Record 160 of Set | baghdad
# Processing Record 161 of Set | bousso
# Processing Record 162 of Set | tiznit
# Processing Record 163 of Set | ponta do sol
# Processing Record 164 of Set | constitucion
# Processing Record 165 of Set | semiletka
# Processing Record 166 of Set | provideniya
# Processing Record 167 of Set | dickinson
# Processing Record 168 of Set | nemuro
# Processing Record 169 of Set | angoche
# Processing Record 170 of Set | mollendo
# Processing Record 171 of Set | sitka
# Processing Record 172 of Set | deogarh
# Processing Record 173 of Set | ribeira grande
# Processing Record 174 of Set | kandi
# Processing Record 175 of Set | kavieng
# Processing Record 176 of Set | sharjah
# Processing Record 177 of Set | kamenka
# Processing Record 178 of Set | hualmay
# Processing Record 179 of Set | dien bien
# City not found... skipping
# Processing Record 180 of Set | marcona
# City not found... skipping
# Processing Record 181 of Set | tuatapere
# Processing Record 182 of Set | barentsburg
# City not found... skipping
# Processing Record 183 of Set | dubbo
# Processing Record 184 of Set | thompson
# Processing Record 185 of Set | milan
# Processing Record 186 of Set | bereda
# Processing Record 187 of Set | tiksi
# Processing Record 188 of Set | kattivakkam
# Processing Record 189 of Set | goundi
# Processing Record 190 of Set | porto belo
# Processing Record 191 of Set | teguise
# Processing Record 192 of Set | hermanus
# Processing Record 193 of Set | yellowknife
# Processing Record 194 of Set | mirante do paranapanema
# Processing Record 195 of Set | asau
# City not found... skipping
# Processing Record 196 of Set | alyangula
# Processing Record 197 of Set | port blair
# Processing Record 198 of Set | lompoc
# Processing Record 199 of Set | boyolangu
# Processing Record 200 of Set | tombouctou
# Processing Record 201 of Set | monrovia
# Processing Record 202 of Set | bitung
# Processing Record 203 of Set | austin
# Processing Record 204 of Set | balimo
# City not found... skipping
# Processing Record 205 of Set | pacific grove
# Processing Record 206 of Set | una
# Processing Record 207 of Set | vila franca do campo
# Processing Record 208 of Set | grand river south east
# City not found... skipping
# Processing Record 209 of Set | oksfjord
# Processing Record 210 of Set | hilo
# Processing Record 211 of Set | vaitupu
# City not found... skipping
# Processing Record 212 of Set | puerto del rosario
# Processing Record 213 of Set | baykit
# Processing Record 214 of Set | tullow
# Processing Record 215 of Set | hamilton
# Processing Record 216 of Set | dzhusaly
# City not found... skipping
# Processing Record 217 of Set | clearwater
# Processing Record 218 of Set | orbetello
# Processing Record 219 of Set | esperance
# Processing Record 220 of Set | rongcheng
# Processing Record 221 of Set | pangody
# Processing Record 222 of Set | brainerd
# Processing Record 223 of Set | illoqqortoormiut
# City not found... skipping
# Processing Record 224 of Set | hay river
# Processing Record 225 of Set | carroll
# Processing Record 226 of Set | tateyama
# Processing Record 227 of Set | iqaluit
# Processing Record 228 of Set | zhangye
# Processing Record 229 of Set | deputatskiy
# Processing Record 230 of Set | tasiilaq
# Processing Record 231 of Set | sao felix do xingu
# Processing Record 232 of Set | lorengau
# Processing Record 233 of Set | burica
# City not found... skipping
# Processing Record 234 of Set | trairi
# Processing Record 235 of Set | catamarca
# Processing Record 236 of Set | moerai
# Processing Record 237 of Set | hovd
# Processing Record 238 of Set | tabalosos
# Processing Record 239 of Set | mongoumba
# Processing Record 240 of Set | itaituba
# Processing Record 241 of Set | malwan
# City not found... skipping
# Processing Record 242 of Set | ngukurr
# City not found... skipping
# Processing Record 243 of Set | yulara
# Processing Record 244 of Set | bilibino
# Processing Record 245 of Set | codrington
# Processing Record 246 of Set | maniitsoq
# Processing Record 247 of Set | nexo
# Processing Record 248 of Set | sungai siput utara
# City not found... skipping
# Processing Record 249 of Set | kuche
# City not found... skipping
# Processing Record 250 of Set | north bend
# Processing Record 251 of Set | salinopolis
# Processing Record 252 of Set | tarudant
# City not found... skipping
# Processing Record 253 of Set | nueve de julio
# Processing Record 254 of Set | taltal
# Processing Record 255 of Set | broken hill
# Processing Record 256 of Set | saint-joseph
# Processing Record 257 of Set | alice springs
# Processing Record 258 of Set | mandali
# Processing Record 259 of Set | petropavl
# Processing Record 260 of Set | bathsheba
# Processing Record 261 of Set | tura
# Processing Record 262 of Set | gubkinskiy
# Processing Record 263 of Set | warqla
# City not found... skipping
# Processing Record 264 of Set | roald
# Processing Record 265 of Set | sfantu gheorghe
# Processing Record 266 of Set | liverpool
# Processing Record 267 of Set | poum
# Processing Record 268 of Set | flinders
# Processing Record 269 of Set | pangnirtung
# Processing Record 270 of Set | paslek
# Processing Record 271 of Set | lerwick
# Processing Record 272 of Set | gorkovskoye
# City not found... skipping
# Processing Record 273 of Set | tucupita
# Processing Record 274 of Set | fenoarivo
# Processing Record 275 of Set | paka
# Processing Record 276 of Set | torbay
# Processing Record 277 of Set | mahon
# Processing Record 278 of Set | tsihombe
# City not found... skipping
# Processing Record 279 of Set | nanortalik
# Processing Record 280 of Set | dodola
# Processing Record 281 of Set | kamaishi
# Processing Record 282 of Set | east london
# Processing Record 283 of Set | geraldton
# Processing Record 284 of Set | amderma
# City not found... skipping
# Processing Record 285 of Set | arlit
# Processing Record 286 of Set | borlange
# City not found... skipping
# Processing Record 287 of Set | kanlagay
# Processing Record 288 of Set | caravelas
# Processing Record 289 of Set | damghan
# Processing Record 290 of Set | namatanai
# Processing Record 291 of Set | severo-kurilsk
# Processing Record 292 of Set | kamiiso
# Processing Record 293 of Set | santa cruz
# Processing Record 294 of Set | asfi
# Processing Record 295 of Set | puerto ayacucho
# Processing Record 296 of Set | rumoi
# Processing Record 297 of Set | tahta
# Processing Record 298 of Set | suao
# City not found... skipping
# Processing Record 299 of Set | srivardhan
# Processing Record 300 of Set | jiayuguan
# Processing Record 301 of Set | dujuma
# City not found... skipping
# Processing Record 302 of Set | novoagansk
# Processing Record 303 of Set | salinas
# Processing Record 304 of Set | santa maria
# Processing Record 305 of Set | asyut
# Processing Record 306 of Set | naklo nad notecia
# Processing Record 307 of Set | itarema
# Processing Record 308 of Set | cockburn town
# Processing Record 309 of Set | puerto escondido
# Processing Record 310 of Set | navahrudak
# Processing Record 311 of Set | buarcos
# Processing Record 312 of Set | mehamn
# Processing Record 313 of Set | berlevag
# Processing Record 314 of Set | santo antonio da platina
# Processing Record 315 of Set | pontes e lacerda
# Processing Record 316 of Set | americus
# Processing Record 317 of Set | tyrma
# Processing Record 318 of Set | badulla
# Processing Record 319 of Set | bilma
# Processing Record 320 of Set | carnarvon
# Processing Record 321 of Set | mungwi
# Processing Record 322 of Set | egvekinot
# Processing Record 323 of Set | aranos
# Processing Record 324 of Set | evensk
# Processing Record 325 of Set | benicarlo
# Processing Record 326 of Set | iringa
# Processing Record 327 of Set | isla mujeres
# Processing Record 328 of Set | skjervoy
# Processing Record 329 of Set | alice
# Processing Record 330 of Set | padang
# Processing Record 331 of Set | burayevo
# Processing Record 332 of Set | aklavik
# Processing Record 333 of Set | gizo
# Processing Record 334 of Set | fortuna
# Processing Record 335 of Set | wagar
# Processing Record 336 of Set | camana
# Processing Record 337 of Set | iralaya
# Processing Record 338 of Set | muros
# Processing Record 339 of Set | sur
# Processing Record 340 of Set | svetlaya
# Processing Record 341 of Set | zhezkazgan
# Processing Record 342 of Set | mahajanga
# Processing Record 343 of Set | alugan
# Processing Record 344 of Set | eagle pass
# Processing Record 345 of Set | vestmannaeyjar
# Processing Record 346 of Set | veinticinco de mayo
# Processing Record 347 of Set | kilcullen
# Processing Record 348 of Set | san cristobal
# Processing Record 349 of Set | inhambane
# Processing Record 350 of Set | ilhabela
# Processing Record 351 of Set | biltine
# Processing Record 352 of Set | chapais
# Processing Record 353 of Set | duz
# City not found... skipping
# Processing Record 354 of Set | luxor
# Processing Record 355 of Set | nelson bay
# Processing Record 356 of Set | bubaque
# Processing Record 357 of Set | pevek
# Processing Record 358 of Set | kirakira
# Processing Record 359 of Set | ust-kamchatsk
# City not found... skipping
# Processing Record 360 of Set | sug-aksy
# City not found... skipping
# Processing Record 361 of Set | iki-burul
# Processing Record 362 of Set | imbituba
# Processing Record 363 of Set | sambava
# Processing Record 364 of Set | mus
# Processing Record 365 of Set | talnakh
# Processing Record 366 of Set | kahului
# Processing Record 367 of Set | talcahuano
# Processing Record 368 of Set | guanica
# Processing Record 369 of Set | mayumba
# Processing Record 370 of Set | lucapa
# Processing Record 371 of Set | ust-kut
# Processing Record 372 of Set | lishu
# Processing Record 373 of Set | urumqi
# Processing Record 374 of Set | muli
# Processing Record 375 of Set | guajara-mirim
# City not found... skipping
# Processing Record 376 of Set | khonsa
# Processing Record 377 of Set | gudur
# Processing Record 378 of Set | itatuba
# Processing Record 379 of Set | sao filipe
# Processing Record 380 of Set | grindavik
# Processing Record 381 of Set | sehithwa
# Processing Record 382 of Set | santiago del estero
# Processing Record 383 of Set | pechenga
# Processing Record 384 of Set | pak phanang
# Processing Record 385 of Set | ekhabi
# Processing Record 386 of Set | reconquista
# Processing Record 387 of Set | ladysmith
# Processing Record 388 of Set | gornopravdinsk
# Processing Record 389 of Set | vega de alatorre
# Processing Record 390 of Set | caldwell
# Processing Record 391 of Set | rawson
# Processing Record 392 of Set | terbuny
# Processing Record 393 of Set | tromso
# Processing Record 394 of Set | kieta
# Processing Record 395 of Set | mount isa
# Processing Record 396 of Set | lantana
# Processing Record 397 of Set | fukuma
# Processing Record 398 of Set | brest
# Processing Record 399 of Set | rudnyy
# Processing Record 400 of Set | tigil
# Processing Record 401 of Set | catalao
# Processing Record 402 of Set | pisco
# Processing Record 403 of Set | cherskiy
# Processing Record 404 of Set | cabo san lucas
# Processing Record 405 of Set | fez
# Processing Record 406 of Set | boulder
# Processing Record 407 of Set | maun
# Processing Record 408 of Set | douentza
# Processing Record 409 of Set | hamada
# Processing Record 410 of Set | mazagao
# Processing Record 411 of Set | valparaiso
# Processing Record 412 of Set | cintalapa
# Processing Record 413 of Set | gouyave
# Processing Record 414 of Set | bargal
# City not found... skipping
# Processing Record 415 of Set | inta
# Processing Record 416 of Set | sakakah
# Processing Record 417 of Set | pakwach
# City not found... skipping
# Processing Record 418 of Set | ambatondrazaka
# Processing Record 419 of Set | fukue
# Processing Record 420 of Set | vangaindrano
# Processing Record 421 of Set | cayenne
# Processing Record 422 of Set | pescara
# Processing Record 423 of Set | antofagasta
# Processing Record 424 of Set | hithadhoo
# Processing Record 425 of Set | cap malheureux
# Processing Record 426 of Set | bar harbor
# Processing Record 427 of Set | inuvik
# Processing Record 428 of Set | afsin
# Processing Record 429 of Set | grand centre
# City not found... skipping
# Processing Record 430 of Set | arrecife
# Processing Record 431 of Set | carbonear
# Processing Record 432 of Set | kegayli
# City not found... skipping
# Processing Record 433 of Set | vao
# Processing Record 434 of Set | taoudenni
# Processing Record 435 of Set | margate
# Processing Record 436 of Set | marsa matruh
# Processing Record 437 of Set | fairbanks
# Processing Record 438 of Set | hami
# Processing Record 439 of Set | te anau
# Processing Record 440 of Set | tessalit
# Processing Record 441 of Set | tagusao
# Processing Record 442 of Set | adra
# Processing Record 443 of Set | fairview
# Processing Record 444 of Set | mashivka
# Processing Record 445 of Set | faya
# Processing Record 446 of Set | kargasok
# Processing Record 447 of Set | havelock
# Processing Record 448 of Set | buraydah
# Processing Record 449 of Set | suruc
# Processing Record 450 of Set | sompeta
# Processing Record 451 of Set | morant bay
# Processing Record 452 of Set | kristiinankaupunki
# Processing Record 453 of Set | ksenyevka
# City not found... skipping
# Processing Record 454 of Set | nenjiang
# Processing Record 455 of Set | saint-georges
# Processing Record 456 of Set | irbeyskoye
# Processing Record 457 of Set | port hedland
# Processing Record 458 of Set | avera
# Processing Record 459 of Set | souillac
# Processing Record 460 of Set | ilulissat
# Processing Record 461 of Set | saint george
# Processing Record 462 of Set | ubinskoye
# Processing Record 463 of Set | tsaratanana
# Processing Record 464 of Set | salalah
# Processing Record 465 of Set | kaseda
# Processing Record 466 of Set | tabialan
# City not found... skipping
# Processing Record 467 of Set | beloha
# Processing Record 468 of Set | georgetown
# Processing Record 469 of Set | nome
# Processing Record 470 of Set | tidore
# City not found... skipping
# Processing Record 471 of Set | ballina
# Processing Record 472 of Set | sorland
# Processing Record 473 of Set | los llanos de aridane
# Processing Record 474 of Set | ranong
# Processing Record 475 of Set | la palma
# Processing Record 476 of Set | tambura
# Processing Record 477 of Set | zhanakorgan
# Processing Record 478 of Set | paamiut
# Processing Record 479 of Set | hanzhong
# Processing Record 480 of Set | porto velho
# Processing Record 481 of Set | yeppoon
# Processing Record 482 of Set | tumannyy
# City not found... skipping
# Processing Record 483 of Set | quchan
# Processing Record 484 of Set | port-de-paix
# City not found... skipping
# Processing Record 485 of Set | lindsay
# Processing Record 486 of Set | jacareacanga
# Processing Record 487 of Set | buala
# Processing Record 488 of Set | veraval
# Processing Record 489 of Set | rancho palos verdes
# Processing Record 490 of Set | komsomolskiy
# Processing Record 491 of Set | warrington
# Processing Record 492 of Set | scarborough
# Processing Record 493 of Set | samarai
# Processing Record 494 of Set | laguna
# Processing Record 495 of Set | zhuhai
# Processing Record 496 of Set | college
# Processing Record 497 of Set | san juan
# Processing Record 498 of Set | norman wells
# Processing Record 499 of Set | coquimbo
# Processing Record 500 of Set | corn island
# Processing Record 501 of Set | saint anthony
# Processing Record 502 of Set | westport
# Processing Record 503 of Set | zabaykalsk
# Processing Record 504 of Set | maraa
# Processing Record 505 of Set | laureles
# Processing Record 506 of Set | zhigansk
# Processing Record 507 of Set | hit
# Processing Record 508 of Set | nobeoka
# Processing Record 509 of Set | straumen
# Processing Record 510 of Set | bud
# Processing Record 511 of Set | am timan
# Processing Record 512 of Set | ongandjera
# Processing Record 513 of Set | garissa
# Processing Record 514 of Set | okha
# Processing Record 515 of Set | pimentel
# Processing Record 516 of Set | shache
# Processing Record 517 of Set | kununurra
# Processing Record 518 of Set | dahod
# Processing Record 519 of Set | tazmalt
# Processing Record 520 of Set | acapulco
# Processing Record 521 of Set | shieli
# Processing Record 522 of Set | lamu
# Processing Record 523 of Set | monster
# Processing Record 524 of Set | kolyvan
# Processing Record 525 of Set | saryshagan
# City not found... skipping
# Processing Record 526 of Set | kamsack
# Processing Record 527 of Set | sadao
# Processing Record 528 of Set | kifri
# Processing Record 529 of Set | chitral
# Processing Record 530 of Set | buzmeyin
# Processing Record 531 of Set | la romana
# Processing Record 532 of Set | visby
# Processing Record 533 of Set | la rioja
# Processing Record 534 of Set | umm lajj
# Processing Record 535 of Set | bowen
# Processing Record 536 of Set | hengyang
# Processing Record 537 of Set | pekalongan
# Processing Record 538 of Set | ixtapa
# Processing Record 539 of Set | formosa
# Processing Record 540 of Set | volnovakha
# Processing Record 541 of Set | svencionys
# Processing Record 542 of Set | wamba
# Processing Record 543 of Set | makarov
# Processing Record 544 of Set | meulaboh
# Processing Record 545 of Set | pasighat
# Processing Record 546 of Set | tabas
# Processing Record 547 of Set | kaduqli
# Processing Record 548 of Set | lavumisa
# Processing Record 549 of Set | usinsk
# Processing Record 550 of Set | andenes
# Processing Record 551 of Set | ahipara
# Processing Record 552 of Set | high level
# Processing Record 553 of Set | puerto madryn
# Processing Record 554 of Set | umzimvubu
# City not found... skipping
# Processing Record 555 of Set | temaraia
# City not found... skipping
# Processing Record 556 of Set | krasnoarmeysk
# Processing Record 557 of Set | poco branco
# Processing Record 558 of Set | tres de maio
# Processing Record 559 of Set | savannakhet
# Processing Record 560 of Set | kongwa
# Processing Record 561 of Set | birjand
# Processing Record 562 of Set | verkhnetulomskiy
# Processing Record 563 of Set | sechura
# Processing Record 564 of Set | kruisfontein
# Processing Record 565 of Set | marovoay
# Processing Record 566 of Set | labutta
# City not found... skipping
# Processing Record 567 of Set | sibolga
# Processing Record 568 of Set | waitati
# Processing Record 569 of Set | lavrentiya
# Processing Record 570 of Set | coulihaut
# City not found... skipping
# Processing Record 571 of Set | sobolevo
# Processing Record 572 of Set | iwanai
# Processing Record 573 of Set | yuli
# Processing Record 574 of Set | olafsvik
# Processing Record 575 of Set | polonnaruwa
# Processing Record 576 of Set | macon
# Processing Record 577 of Set | pyay
# Processing Record 578 of Set | pundaguitan
# Processing Record 579 of Set | maldonado
# Processing Record 580 of Set | okhotsk
# Processing Record 581 of Set | amga
# Processing Record 582 of Set | jevicko
# Processing Record 583 of Set | mersing
# Processing Record 584 of Set | chany
# Processing Record 585 of Set | kavaratti
# Processing Record 586 of Set | isangel
# Processing Record 587 of Set | waingapu
# Processing Record 588 of Set | airai
# Processing Record 589 of Set | vagay
# Processing Record 590 of Set | dunedin
# Processing Record 591 of Set | sisimiut
# Processing Record 592 of Set | ahuimanu
# Processing Record 593 of Set | camacha
# Processing Record 594 of Set | terenga
# City not found... skipping
# Processing Record 595 of Set | lima
# Processing Record 596 of Set | eydhafushi
# Processing Record 597 of Set | unye
# City not found... skipping
# Processing Record 598 of Set | luena
# Processing Record 599 of Set | yaan
# Processing Record 600 of Set | tautira
# Processing Record 601 of Set | mbuyapey
# Processing Record 602 of Set | capesterre-belle-eau
# Processing Record 603 of Set | bababe
# City not found... skipping
# Processing Record 604 of Set | teguldet
# Processing Record 605 of Set | rawannawi
# City not found... skipping
# Processing Record 606 of Set | kampot
# Processing Record 607 of Set | mirnyy
# Processing Record 608 of Set | olavarria
# Processing Record 609 of Set | bayan
# Processing Record 610 of Set | gulshat
# City not found... skipping
# Processing Record 611 of Set | katsuura
# Processing Record 612 of Set | cairns
# Processing Record 613 of Set | nador
# Processing Record 614 of Set | marsabit
# Processing Record 615 of Set | carutapera
# Processing Record 616 of Set | zhucheng
# Processing Record 617 of Set | ojinaga
# Processing Record 618 of Set | adamovka
# Processing Record 619 of Set | gorahun
# Processing Record 620 of Set | kutum
# Processing Record 621 of Set | lokbatan
# Processing Record 622 of Set | ust-kuyga
# Processing Record 623 of Set | beringovskiy
# Processing Record 624 of Set | gurupi
# Processing Record 625 of Set | saint-pierre
# Processing Record 626 of Set | quelimane
# Processing Record 627 of Set | juneau
# Processing Record 628 of Set | leshukonskoye
# Processing Record 629 of Set | la ronge
# Processing Record 630 of Set | yilan
# Processing Record 631 of Set | varadero
# Processing Record 632 of Set | denpasar
# Processing Record 633 of Set | muzhi
# Processing Record 634 of Set | manoharpur
# Processing Record 635 of Set | tabiauea
# City not found... skipping
# Processing Record 636 of Set | narathiwat
# Processing Record 637 of Set | albanel
# Processing Record 638 of Set | altay
# Processing Record 639 of Set | dondo
# Processing Record 640 of Set | baker city

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.count()
# Out:
# City          641
# Cloudiness    641
# Country       641
# Date          641
# Humidity      641
# Lat           641
# Lng           641
# Max Temp      641
# Wind Speed    641
# dtype: int64

# %%
#Convert empty rows to NaN
cities_df.replace(r'^\s*$', np.nan, regex=True, inplace = True)

#Drop empty rows
cities_df = cities_df.dropna(axis = 0, how ='any') 

#Preview dataframe
cities_df.head()
# Out:
#               City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0        flagstaff         1.0      US  1.578688e+09      57.0  35.20 -111.65
# 1           hasaki        75.0      JP  1.578688e+09      86.0  35.73  140.83
# 2     port lincoln        62.0      AU  1.578688e+09      70.0 -34.73  135.87
# 4  lazaro cardenas         0.0      MX  1.578688e+09      36.0  17.96 -102.20
# 5             lebu         0.0      CL  1.578688e+09      52.0 -37.62  -73.65
#
#    Max Temp  Wind Speed
# 0    283.71        1.50
# 1    276.15        2.60
# 2    289.26        5.42
# 4    306.96        2.17
# 5    291.93        5.27

# %%
#Save as csv
cities_df.to_csv("cities_weather_data.csv", encoding="utf-8", index=False)

#Preview Dataframe
cities_df.head()
# Out:
#               City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0        flagstaff         1.0      US  1.578688e+09      57.0  35.20 -111.65
# 1           hasaki        75.0      JP  1.578688e+09      86.0  35.73  140.83
# 2     port lincoln        62.0      AU  1.578688e+09      70.0 -34.73  135.87
# 4  lazaro cardenas         0.0      MX  1.578688e+09      36.0  17.96 -102.20
# 5             lebu         0.0      CL  1.578688e+09      52.0 -37.62  -73.65
#
#    Max Temp  Wind Speed
# 0    283.71        1.50
# 1    276.15        2.60
# 2    289.26        5.42
# 4    306.96        2.17
# 5    291.93        5.27

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_values = cities_df["Lat"].astype(float)
y_values = cities_df["Max Temp"].astype(float)
plt.scatter(x_values, y_values)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
